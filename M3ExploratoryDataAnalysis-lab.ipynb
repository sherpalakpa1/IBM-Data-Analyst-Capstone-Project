# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Exploratory Data Analysis Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this module you get to work with the cleaned dataset from the previous module.
#
# In this assignment you will perform the task of exploratory data analysis.
# You will find out the distribution of data, presence of outliers and also determine the correlation between different columns in the dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Identify the distribution of data in the dataset.
#
# -   Identify outliers in the dataset.
#
# -   Remove outliers from the dataset.
#
# -   Identify correlation between features in the dataset.

# %% [markdown]
# * * *

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import the pandas module.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# %% [markdown]
# ## Distribution

# %% [markdown]
# ### Determine how the data is distributed

# %% [markdown]
# The column `ConvertedComp` contains Salary converted to annual USD salaries using the exchange rate on 2019-02-01.
#
# This assumes 12 working months and 50 working weeks.

# %% [markdown]
# Plot the distribution curve for the column `ConvertedComp`.

# %%
# your code goes here
plt.figure(figsize=(10,10))
df['ConvertedComp'].plot(kind='kde')
plt.show()

# %% [markdown]
# Plot the histogram for the column `ConvertedComp`.

# %%
# your code goes here
plt.figure(figsize=(10,10))
df['ConvertedComp'].plot(kind='hist',bins=10)
plt.show()

# %% [markdown]
# What is the median of the column `ConvertedComp`?

# %%
# your code goes here
df['ConvertedComp'].median()
# Out:
# 57745.0

# %% [markdown]
# How many responders identified themselves only as a **Man**?

# %%
# your code goes here
df.Gender.value_counts()
# Out:
# Man                                                            10480
# Woman                                                            731
# Non-binary, genderqueer, or gender non-conforming                 63
# Man;Non-binary, genderqueer, or gender non-conforming             26
# Woman;Non-binary, genderqueer, or gender non-conforming           14
# Woman;Man                                                          9
# Woman;Man;Non-binary, genderqueer, or gender non-conforming        2
# Name: Gender, dtype: int64

# %% [markdown]
# Find out the  median ConvertedComp of responders identified themselves only as a **Woman**?

# %%
# your code goes here
df_cc_woman = df.groupby('Gender')['ConvertedComp'].median().reset_index()
df_cc_woman = df_cc_woman[df_cc_woman['Gender']=='Woman']
df_cc_woman
# Out:
#   Gender  ConvertedComp
# 3  Woman        57708.0

# %% [markdown]
# Give the five number summary for the column `Age`?

# %% [markdown]
# **Double click here for hint**.
#
# <!--
# min,q1,median,q3,max of a column are its five number summary.
# -->

# %%
# your code goes here
df.Age.describe()
# Out:
# count    11111.000000
# mean        30.778895
# std          7.393686
# min         16.000000
# 25%         25.000000
# 50%         29.000000
# 75%         35.000000
# max         99.000000
# Name: Age, dtype: float64

# %% [markdown]
# Plot a histogram of the column `Age`.

# %%
# 16, 99
99/8
# Out:
# 12.375

# %%
# your code goes here
plt.figure(figsize=(10,10))
df['Age'].plot(kind='hist',bins=10, grid=True)
plt.tight_layout()

# %% [markdown]
# ## Outliers

# %% [markdown]
# ### Finding outliers

# %% [markdown]
# Find out if outliers exist in the column `ConvertedComp` using a box plot?

# %%
# your code goes here
plt.figure(figsize=(5,10))
sns.boxplot(data=df['ConvertedComp'])
plt.tight_layout()

# %% [markdown]
# Find out the Inter Quartile Range for the column `ConvertedComp`.

# %%
# your code goes here
df.ConvertedComp.describe()
# Out:
# count    1.058200e+04
# mean     1.315967e+05
# std      2.947865e+05
# min      0.000000e+00
# 25%      2.686800e+04
# 50%      5.774500e+04
# 75%      1.000000e+05
# max      2.000000e+06
# Name: ConvertedComp, dtype: float64

# %%
Q1=df.ConvertedComp.quantile(0.25)
Q3=df.ConvertedComp.quantile(0.75)
IQR = Q3-Q1
print(IQR)
# Out:
# 73132.0

# %% [markdown]
# Find out the upper and lower bounds.

# %%
# your code goes here
upperbound = Q3 + (1.5*IQR) 
lowerbound = Q1 - (1.5*IQR)
print(upperbound,lowerbound)
# Out:
# 209698.0 -82830.0

# %% [markdown]
# Identify how many outliers are there in the `ConvertedComp` column.

# %%
# your code goes here
(df['ConvertedComp']<-82830).sum() + (df['ConvertedComp']>209698.0).sum()
# Out:
# 879

# %% [markdown]
# Create a new dataframe by removing the outliers from the `ConvertedComp` column.

# %%
df[(df['ConvertedComp']>upperbound) | (df['ConvertedComp']<lowerbound)]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 3              16                     I am a developer by profession      Yes
# 13             32                     I am a developer by profession       No
# 45            100                     I am a developer by profession      Yes
# 46            102                     I am a developer by profession       No
# 60            128  I am not primarily a developer, but I write co...      Yes
# ...           ...                                                ...      ...
# 11296       24915                     I am a developer by profession      Yes
# 11303       24931                     I am a developer by profession       No
# 11350       25036                     I am a developer by profession      Yes
# 11353       25047                     I am a developer by profession      Yes
# 11369       25086                     I am a developer by profession      Yes
#
# ...

# %%
# your code goes here
# check the number of rows and column of the dataframe
print('df',df.shape)
# drop the outliers from the dataframe
new_df = df.drop(df[(df['ConvertedComp']>upperbound) | (df['ConvertedComp']<lowerbound)].index)
# check the new number of rows of the dataframe
print('new_df',new_df.shape)
# Out:
# df (11398, 85)
# new_df (10519, 85)

# %%
# median convertedcomp after removing the outliers
new_df['ConvertedComp'].median()
# Out:
# 52704.0

# %%
# find important statistics of the ConvertedComp after removing outliers
new_df['ConvertedComp'].describe()
# Out:
# count      9703.000000
# mean      59883.208389
# std       43394.336755
# min           0.000000
# 25%       24060.000000
# 50%       52704.000000
# 75%       85574.500000
# max      209356.000000
# Name: ConvertedComp, dtype: float64

# %% [markdown]
# ## Correlation

# %% [markdown]
# ### Finding correlation

# %% [markdown]
# Find the correlation between `Age` and all other numerical columns.

# %%
# your code goes here
print('df', df.corr()['Age'].reset_index())
print('\n')
print('new_df',new_df.corr()['Age'].reset_index())
# Out:
# df            index       Age
# 0     Respondent  0.004041
# 1      CompTotal  0.006970
# 2  ConvertedComp  0.105386
# 3    WorkWeekHrs  0.036518
# 4     CodeRevHrs -0.020469
# 5            Age  1.000000
#
#
# new_df            index       Age
# 0     Respondent  0.003950
# 1      CompTotal  0.006371
# 2  ConvertedComp  0.401821
# 3    WorkWeekHrs  0.037452
# 4     CodeRevHrs -0.017961
# 5            Age  1.000000

# %%
plt.figure(figsize=(10,10))
sns.regplot(data=new_df,x='Age',y='ConvertedComp')
plt.show()
# Out:
# C:\Users\lakpa\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
